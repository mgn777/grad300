# %%
# Force reload of the pipeline module to get latest changes
import sys
if 'grad300' in sys.modules:
    del sys.modules['grad300']
    del sys.modules['grad300.pipeline']
    del sys.modules['grad300.plotting']
    del sys.modules['grad300.io']

    

# Now reimport
from grad300 import GradPipeline

pipe = GradPipeline()
pipe.run("20250212", "SUN", window=5)
# Out:
# === GRAD-300 20250212 SUN ===
# tpis: 4
# spectrums: 1
# images: 4
#
# 🎯 SUN - 143921
# WARNING: File may have been truncated: actual file length (546360) is smaller than the expected size (547200) [astropy.io.fits.file]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# DIAMETER =                    0  / TELESCOPE diameter                            [astropy.io.fits.card]
#   --- Reconstruction d'image ---
#   Image originale: 27x27
#   Région utile détectée: 27x26 (pixels 0-26, 0-25)
#   Taux de remplissage: 96.3%
#   Résolution utilisée: 26 x 26
#   ✅ Résolution finale SUN: 26x26 (couverture = 84.5%, 571 pixels occupés)
# WARNING: File may have been truncated: actual file length (7218) is smaller than the expected size (8640) [astropy.io.fits.file]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ...

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy import stats
import pandas as pd
from astropy.wcs import WCS
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz, get_sun
import astropy.units as u
from scipy.signal import savgol_filter
from datetime import datetime
import shutil
import os
import glob
import re

# %%
# The pipeline has been refactored into a proper Python package.
# Instead of redefining the class here we import and use the module.

from grad300 import GradPipeline

# You can still experiment interactively using the class:
pipe = GradPipeline()
pipe.run("20250212", "SUN", window=5)
# Out:
# === GRAD-300 20250212 SUN ===
# spectrums: 1
# tpis: 4
# images: 4
#
# 📊 SUN - 083051
#   ✅ Sauvegardé
#
# 🎯 SUN - 143921
# WARNING: File may have been truncated: actual file length (60900) is smaller than the expected size (63360) [astropy.io.fits.file]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# DIAMETER =                    3  / TELESCOPE diameter                            [astropy.io.fits.card]
# WARNING: File may have been truncated: actual file length (546360) is smaller than the expected size (547200) [astropy.io.fits.file]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# DIAMETER =                    0  / TELESCOPE diameter                            [astropy.io.fits.card]
#   --- Reconstruction d'image ---
#      💾 Résolution optimale: 43x43 (ratio=0.6306)
#   Image originale: 51x51
#   Région utile détectée: 51x51 (pixels 0-50, 0-50)
# ...

# %%
# reconstituer limage après cleaning 
# mettre le temps en secondes dans le spectrum ? 
# remplacer le 3eme plot par qqch de plus parlant (acceleration ra dec ?)
